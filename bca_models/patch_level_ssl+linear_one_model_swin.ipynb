# %%
from PIL import Image
from rl_benchmarks.models import iBOTViT, iBOTSwin
from openslide import open_slide
from openslide.deepzoom import DeepZoomGenerator
import pathlib
from tqdm import tqdm
from PIL import Image
import numpy as np
Image.MAX_IMAGE_PIXELS = None
from torchvision import transforms
import torch
from torch.utils.data import Dataset
import os
from multiprocessing import Pool
import umap
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from rl_benchmarks.utils.linear_evaluation import get_binary_class_metrics, get_bootstrapped_metrics, dict_to_dataframe
import umap.plot
# Out:
# /home/yuxin/miniconda3/envs/histosslscaling/lib/python3.8/site-packages/umap/plot.py:203: NumbaDeprecationWarning: The keyword argument 'nopython=False' was supplied. From Numba 0.59.0 the default is being changed to True and use of 'nopython=False' will raise a warning as the argument will have no effect. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit(nopython=False)

# %%
# device = "cuda:0" if torch.cuda.is_available() else "cpu"
device = 'cpu'
# weights_path = '/home/yuxin/Downloads/ibot_vit_base_pancan.pth'
# weights_path = '/home/yuxin/Downloads/checkpoint0040.pth'
weights_path = '/home/yuxin/Downloads/swin_ckpt.pth'
# ibot_base_pancancer = iBOTViT(architecture="vit_base_pancan", encoder="teacher", weights_path=weights_path).to(device)
ibot_base_pancancer =iBOTSwin(architecture="swin_base", encoder="teacher", weights_path=weights_path).to(device)
# Out:
# 2024-02-01 15:13:26.733 | INFO     | rl_benchmarks.models.feature_extractors.ibot_vit:__init__:181 - Pretrained weights found at /home/yuxin/Downloads/swin_ckpt.pth and loaded with msg: _IncompatibleKeys(missing_keys=['masked_embed', 'head.weight', 'head.bias'], unexpected_keys=['head.mlp.0.weight', 'head.mlp.0.bias', 'head.mlp.2.weight', 'head.mlp.2.bias', 'head.mlp.4.weight', 'head.mlp.4.bias', 'head.last_layer.weight_g', 'head.last_layer.weight_v', 'head.last_layer2.weight_g', 'head.last_layer2.weight_v'])

# %%
patch_size = 224
data_root = pathlib.Path('/mnt/hd0/ssd/SUQH_10x336')
# model_root = pathlib.Path('/home/yuxin/ssd_data/SUQH_10x_tiles/model_balanced')
test_root = pathlib.Path('/home/yuxin/ssd_data/SUQH_10x336/test')
phases = ['train', 'val', 'test']
# save_root = pathlib.Path('/mnt/hd0/project_large_files/bcacad/pretrain_ssl_SUQH_10x336_tiles_model_balanced_features')
save_root = pathlib.Path('/mnt/hd0/project_large_files/bcacad/finetune_ibot_swin')
save_root.mkdir(exist_ok=True)
data_trans = transforms.Compose([
                                # transforms.CenterCrop(336),
                                transforms.Resize(patch_size),
                                ibot_base_pancancer.transform,
                                ])

# %%
def get_type_grade(path):
    type_grade = path.parent.name
    if type_grade == 'normal':
        return 0,0
    elif type_grade == 'tis-1':
        return 1,0
    elif type_grade == 'tis-2':
        return 1,1
    elif type_grade == 'tis-3':
        return 1,2
    elif type_grade == 'it-1':
        return 2,0
    elif type_grade == 'it-2':
        return 2,1
    elif type_grade == 'it-3':
        return 2,2

# %%
X = {
    'train': [],
    'val': [],
    'test': []
}
Y = {
    'train': [],
    'val': [],
    'test': []
}
for phase in phases:
    phase_root = data_root / phase
    # if phase == 'model':
    #     tile_paths = list(phase_root.glob('**/*.png'))
    # else:
    tile_paths = list(phase_root.glob('**/*.jpg'))
    for path in tqdm(tile_paths, desc=f'Processing {phase}'):
        save_path = save_root / phase / path.parent.name /f'{path.stem}.npy' 
        if save_path.exists():
            feature = np.load(save_path)
        else:
            save_path.parent.mkdir(exist_ok=True, parents=True)
            im = Image.open(path)
            tensor = data_trans(im)
            batch = tensor.unsqueeze(0)
            batch = batch.to(device)
            feature = ibot_base_pancancer(batch).detach().cpu().numpy()
            feature = feature.flatten()
            np.save(save_path, feature)
        X[phase].append(feature)
        type, grade = get_type_grade(path)
        Y[phase].append([type, grade])
# Out:
# Processing train: 100%|██████████| 149856/149856 [8:08:13<00:00,  5.12it/s]
# Processing val: 100%|██████████| 37465/37465 [2:14:22<00:00,  4.65it/s]
# Processing test: 100%|██████████| 47330/47330 [2:48:17<00:00,  4.69it/s]

# %%
feature.shape
# Out:
# (1024,)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

def plot_confusion_matrix(confusion_matrix, labels):
    fig, ax = plt.subplots(figsize=(8, 6))
    sns.heatmap(confusion_matrix, annot=True, fmt="d", cmap="Blues", cbar=False, ax=ax)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')
    ax.set_xticklabels(labels)
    ax.set_yticklabels(labels)
    plt.title('Confusion Matrix')
    plt.show()

# %%
def get_metrics(labels, scores, class_names, phase='test'):
    n_resamples = 1000
    confidence_level = 0.95

    binary_metrics = {phase:get_binary_class_metrics(labels, scores)}
    bootstrapped_metrics = {phase: get_bootstrapped_metrics(
        labels, scores, n_resamples=n_resamples, confidence_level=confidence_level
    )}

    results_dict = {
        "binary": binary_metrics,
        "bootstrap": bootstrapped_metrics,
    }
    
    results = dict_to_dataframe(
        results_dict, metrics=["auc", "acc", "f1"], class_names=class_names
    )
    return results

# %%
import sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.multioutput import MultiOutputClassifier
import numpy as np

clf = sklearn.linear_model.SGDClassifier(
                loss="log_loss",
                penalty="l2",
                learning_rate="adaptive",
                eta0=1e-4,
                n_jobs=8,
                early_stopping=False,
                random_state=2023,
            )
mclf = MultiOutputClassifier(clf, n_jobs=10)

# %%
mclf.fit(np.array(X['train']+X['val']), np.array(Y['train']+Y['val']))
# Out:
# MultiOutputClassifier(estimator=SGDClassifier(eta0=0.0001,
#                                               learning_rate='adaptive',
#                                               loss='log_loss', n_jobs=8,
#                                               random_state=2023),
#                       n_jobs=10)

# %%
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.multioutput import MultiOutputClassifier
# import numpy as np

# clf = RandomForestClassifier(random_state=2023)
# mclf = MultiOutputClassifier(clf, n_jobs=10)
# mclf.fit(np.array(X['train']+X['val']), np.array(Y['train']+Y['val']))

# %%
# SUQH Type
from metrics3 import report

y_pred = mclf.predict(np.array(X['test']))
y_prob = np.array(mclf.predict_proba(np.array(X['test'])))
y_true = np.array(Y['test'])
tasks = ['type', 'grade']
class_names = {
    'type': ['Normal', 'nonIBC', 'IBC'],
    'grade': ['Low', 'Median', 'High']
}

type_y_pred = y_pred[:, 0]
type_y_prob = y_prob[0, :]
type_y_true = y_true[:, 0]
type_cm = confusion_matrix(type_y_true, type_y_pred)
plot_confusion_matrix(type_cm, class_names['type'])
print(report(type_y_true, type_y_pred, type_y_prob, class_names['type']))
# Out:
# [[15711   416   237]
#  [  128 14669  1954]
#  [   10  2131 12074]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.9987 |  0.0   |   0.9987  |   0.9987  |
# |   1   | 0.961  |  0.0   |   0.961   |   0.9611  |
# |   2   | 0.9579 | 0.0001 |   0.9579  |   0.958   |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.9754  |   0.9913  | 0.9601 |    0.9955   | 0.9793 |  16364  |
# |      1       |  0.8637  |   0.8521  | 0.8757 |    0.9167   | 0.9309 |  16751  |
# |      2       |  0.8479  |   0.8464  | 0.8494 |    0.9338   | 0.9352 |  14215  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.897  |  47330  |
# |  marco avg   |  0.8957  |   0.8966  | 0.8951 |    0.9487   | 0.9485 |  47330  |
# | weighted avg |  0.8976  |   0.8985  | 0.897  |    0.9491   | 0.9489 |  47330  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.9987, 'auc-ci': 0.0, 'auc-lower': 0.9987, 'auc-upper': 0.9987, 'f1-score': 0.9754, 'precision': 0.9913, 'recall': 0.9601, 'specificity': 0.9955, 'NPV': 0.9793, 'support': 16364}, '1': {'auc': 0.961, 'auc-ci': 0.0, 'auc-lower': 0.961, 'auc-upper': 0.9611, 'f1-score': 0.8637, 'precision': 0.8521, 'recall': 0.8757, 'specificity': 0.9167, 'NPV': 0.9309, 'support': 16751}, '2': {'auc': 0.9579, 'auc-ci': 0.0001, 'auc-lower': 0.9579, 'auc-upper': 0.958, 'f1-score': 0.8479, 'precision': 0.8464, 'recall': 0.8494, 'specificity': 0.9338, 'NPV': 0.9352, 'support': 14215}, 'marco avg': {'f1-score': 0.8957, 'precision': 0.8966, 'recall': 0.8951, 'specificity': 0.9487, 'NPV': 0.9485, 'support': 47330}, 'weighted avg': {'f1-score': 0.8976, 'precision': 0.8985, 'recall': 0.897, 'specificity': 0.9491, 'NPV': 0.9489, 'support': 47330}, 'accuracy': 0.897}

# %%
# SUQH nonIBC
tumor_idx = np.where(type_y_true == 1)[0]
grade_y_pred = y_pred[tumor_idx, 1]
grade_y_prob = y_prob[1, tumor_idx]
grade_y_true = y_true[tumor_idx, 1]
grade_cm = confusion_matrix(grade_y_true, grade_y_pred)
plot_confusion_matrix(grade_cm, class_names['grade'])
print(report(grade_y_true, grade_y_pred, grade_y_prob, class_names['grade']))
# Out:
# [[ 343 1459  125]
#  [1154 3966 1955]
#  [ 291 2963 4495]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.681  | 0.0004 |   0.6806  |   0.6813  |
# |   1   | 0.5639 | 0.0003 |   0.5636  |   0.5641  |
# |   2   | 0.7483 | 0.0002 |   0.7481  |   0.7486  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.1847  |   0.1918  | 0.178  |    0.9025   | 0.8941 |   1927  |
# |      1       |  0.513   |   0.4728  | 0.5606 |    0.543    | 0.6282 |   7075  |
# |      2       |  0.6276  |   0.6837  | 0.5801 |    0.7689   | 0.6802 |   7749  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.5256 |  16751  |
# |  marco avg   |  0.4417  |   0.4494  | 0.4395 |    0.7382   | 0.7342 |  16751  |
# | weighted avg |  0.5282  |   0.538   | 0.5256 |    0.6889   | 0.6829 |  16751  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.681, 'auc-ci': 0.0004, 'auc-lower': 0.6806, 'auc-upper': 0.6813, 'f1-score': 0.1847, 'precision': 0.1918, 'recall': 0.178, 'specificity': 0.9025, 'NPV': 0.8941, 'support': 1927}, '1': {'auc': 0.5639, 'auc-ci': 0.0003, 'auc-lower': 0.5636, 'auc-upper': 0.5641, 'f1-score': 0.513, 'precision': 0.4728, 'recall': 0.5606, 'specificity': 0.543, 'NPV': 0.6282, 'support': 7075}, '2': {'auc': 0.7483, 'auc-ci': 0.0002, 'auc-lower': 0.7481, 'auc-upper': 0.7486, 'f1-score': 0.6276, 'precision': 0.6837, 'recall': 0.5801, 'specificity': 0.7689, 'NPV': 0.6802, 'support': 7749}, 'marco avg': {'f1-score': 0.4417, 'precision': 0.4494, 'recall': 0.4395, 'specificity': 0.7382, 'NPV': 0.7342, 'support': 16751}, 'weighted avg': {'f1-score': 0.5282, 'precision': 0.538, 'recall': 0.5256, 'specificity': 0.6889, 'NPV': 0.6829, 'support': 16751}, 'accuracy': 0.5256}

# %%
# SUQH nonIBC
tumor_idx = np.where(type_y_true == 2)[0]
grade_y_pred = y_pred[tumor_idx, 1]
grade_y_prob = y_prob[1, tumor_idx]
grade_y_true = y_true[tumor_idx, 1]
grade_cm = confusion_matrix(grade_y_true, grade_y_pred)
plot_confusion_matrix(grade_cm, class_names['grade'])
print(report(grade_y_true, grade_y_pred, grade_y_prob, class_names['grade']))
# Out:
# [[ 660  521   54]
#  [ 898 5460 2344]
#  [  75 1638 2565]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.8528 | 0.0003 |   0.8524  |   0.8531  |
# |   1   | 0.6661 | 0.0003 |   0.6658  |   0.6663  |
# |   2   | 0.7663 | 0.0003 |   0.766   |   0.7665  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.4603  |   0.4042  | 0.5344 |    0.925    | 0.9543 |   1235  |
# |      1       |  0.6691  |   0.7166  | 0.6274 |    0.6084   | 0.5085 |   8702  |
# |      2       |  0.5551  |   0.5168  | 0.5996 |    0.7587   | 0.8149 |   4278  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.611  |  14215  |
# |  marco avg   |  0.5615  |   0.5459  | 0.5871 |    0.764    | 0.7592 |  14215  |
# | weighted avg |  0.6166  |   0.6294  | 0.611  |    0.6811   | 0.6394 |  14215  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.8528, 'auc-ci': 0.0003, 'auc-lower': 0.8524, 'auc-upper': 0.8531, 'f1-score': 0.4603, 'precision': 0.4042, 'recall': 0.5344, 'specificity': 0.925, 'NPV': 0.9543, 'support': 1235}, '1': {'auc': 0.6661, 'auc-ci': 0.0003, 'auc-lower': 0.6658, 'auc-upper': 0.6663, 'f1-score': 0.6691, 'precision': 0.7166, 'recall': 0.6274, 'specificity': 0.6084, 'NPV': 0.5085, 'support': 8702}, '2': {'auc': 0.7663, 'auc-ci': 0.0003, 'auc-lower': 0.766, 'auc-upper': 0.7665, 'f1-score': 0.5551, 'precision': 0.5168, 'recall': 0.5996, 'specificity': 0.7587, 'NPV': 0.8149, 'support': 4278}, 'marco avg': {'f1-score': 0.5615, 'precision': 0.5459, 'recall': 0.5871, 'specificity': 0.764, 'NPV': 0.7592, 'support': 14215}, 'weighted avg': {'f1-score': 0.6166, 'precision': 0.6294, 'recall': 0.611, 'specificity': 0.6811, 'NPV': 0.6394, 'support': 14215}, 'accuracy': 0.611}

# %%
def get_X_Y(data_root, save_root, phases=['test']):
    X={}
    Y={}
    for task in ['type', 'nonibc', 'ibc']:
        X[task] = {}
        Y[task] = {}
        for phase in phases:
            X[task][phase] = []
            Y[task][phase] = []

    for phase in phases:
        phase_root = data_root / phase
        tile_paths = list(phase_root.glob('**/*.jpg'))
        for path in tqdm(tile_paths, desc=f'Processing {phase}'):
            save_path = save_root / phase / path.parent.name /f'{path.stem}.npy' 
            if save_path.exists():
                feature = np.load(save_path)
            else:
                save_path.parent.mkdir(exist_ok=True, parents=True)
                im = Image.open(path)
                tensor = data_trans(im)
                batch = tensor.unsqueeze(0)
                batch = batch.to(device)
                feature = ibot_base_pancancer(batch).detach().cpu().numpy()
                feature = feature.flatten()
                np.save(save_path, feature)

            type, grade = get_type_grade(path)
            
            X['type'][phase].append(feature)
            Y['type'][phase].append(type)

            if type == 1:
                X['nonibc'][phase].append(feature)
                Y['nonibc'][phase].append(grade)
            elif type == 2:
                X['ibc'][phase].append(feature)
                Y['ibc'][phase].append(grade)
    return X, Y

# %%
qingdao_root = pathlib.Path('/mnt/hd0/project_large_files/bcacad/patches/qingdao_test')
qingdao_save_root = pathlib.Path('/mnt/hd0/project_large_files/bcacad/patches/qingdao_test/test_swin_ibot_features')
qingdao_X, qingdao_Y = get_X_Y(qingdao_root, qingdao_save_root, phases=['test'])
# Out:
# Processing test: 100%|██████████| 5453/5453 [19:12<00:00,  4.73it/s]

# %%
tasks = ['type', 'nonibc', 'ibc']
class_names = {
    'type': ['Normal', 'nonIBC', 'IBC'],
    'nonibc': ['Low', 'Medium', 'High'],
    'ibc': ['Low', 'Medium', 'High'],
}

# %%
X = qingdao_X
Y = qingdao_Y

for task in tasks:
    model = mclf
    preds = model.predict(np.array(X[task]['test']))
    probs = model.predict_proba(np.array(X[task]['test']))
    probs = np.array(probs)
    if task == 'type':
        preds = preds[:, 0]
        probs = probs[0, :]
    else:
        preds = preds[:, 1]
        probs = probs[1, :]
    labels = np.array(Y[task]['test'])
    print(task)
    cm = confusion_matrix(labels, preds)
    plot_confusion_matrix(cm, class_names[task])
    print(report(labels, preds, probs, class_names[task]))
# Out:
# type
# [[  12   10   10]
#  [ 160 1821  343]
#  [  68  258 2771]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.817  | 0.0023 |   0.8148  |   0.8193  |
# |   1   | 0.925  | 0.0002 |   0.9248  |   0.9252  |
# |   2   | 0.9401 | 0.0002 |   0.9399  |   0.9403  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.0882  |    0.05   | 0.375  |    0.9579   | 0.9962 |    32   |
# |      1       |  0.8253  |   0.8717  | 0.7836 |    0.9143   | 0.8505 |   2324  |
# |      2       |  0.8909  |   0.887   | 0.8947 |    0.8502   |  0.86  |   3097  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.8443 |   5453  |
# |  marco avg   |  0.6015  |   0.6029  | 0.6844 |    0.9075   | 0.9022 |   5453  |
# | weighted avg |  0.8582  |   0.8756  | 0.8443 |    0.8782   | 0.8568 |   5453  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.817, 'auc-ci': 0.0023, 'auc-lower': 0.8148, 'auc-upper': 0.8193, 'f1-score': 0.0882, 'precision': 0.05, 'recall': 0.375, 'specificity': 0.9579, 'NPV': 0.9962, 'support': 32}, '1': {'auc': 0.925, 'auc-ci': 0.0002, 'auc-lower': 0.9248, 'auc-upper': 0.9252, 'f1-score': 0.8253, 'precision': 0.8717, 'recall': 0.7836, 'specificity': 0.9143, 'NPV': 0.8505, 'support': 2324}, '2': {'auc': 0.9401, 'auc-ci': 0.0002, 'auc-lower': 0.9399, 'auc-upper': 0.9403, 'f1-score': 0.8909, 'precision': 0.887, 'recall': 0.8947, 'specificity': 0.8502, 'NPV': 0.86, 'support': 3097}, 'marco avg': {'f1-score': 0.6015, 'precision': 0.6029, 'recall': 0.6844, 'specificity': 0.9075, 'NPV': 0.9022, 'support': 5453}, 'weighted avg': {'f1-score': 0.8582, 'precision': 0.8756, 'recall': 0.8443, 'specificity': 0.8782, 'NPV': 0.8568, 'support': 5453}, 'accuracy': 0.8443}
# nonibc
# [[ 14  58  22]
#  [301 427 153]
#  [208 506 635]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.5811 | 0.0012 |   0.5798  |   0.5823  |
# |   1   | 0.5711 | 0.0008 |   0.5703  |   0.5719  |
# |   2   | 0.7067 | 0.0007 |   0.706   |   0.7073  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.0454  |   0.0268  | 0.1489 |    0.7717   | 0.9556 |    94   |
# |      1       |  0.4562  |   0.4309  | 0.4847 |    0.6091   | 0.6594 |   881   |
# |      2       |  0.5882  |   0.784   | 0.4707 |    0.8205   | 0.5284 |   1349  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.463  |   2324  |
# |  marco avg   |  0.3633  |   0.4139  | 0.3681 |    0.7338   | 0.7145 |   2324  |
# | weighted avg |  0.5162  |   0.6195  | 0.463  |    0.7384   | 0.5953 |   2324  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.5811, 'auc-ci': 0.0012, 'auc-lower': 0.5798, 'auc-upper': 0.5823, 'f1-score': 0.0454, 'precision': 0.0268, 'recall': 0.1489, 'specificity': 0.7717, 'NPV': 0.9556, 'support': 94}, '1': {'auc': 0.5711, 'auc-ci': 0.0008, 'auc-lower': 0.5703, 'auc-upper': 0.5719, 'f1-score': 0.4562, 'precision': 0.4309, 'recall': 0.4847, 'specificity': 0.6091, 'NPV': 0.6594, 'support': 881}, '2': {'auc': 0.7067, 'auc-ci': 0.0007, 'auc-lower': 0.706, 'auc-upper': 0.7073, 'f1-score': 0.5882, 'precision': 0.784, 'recall': 0.4707, 'specificity': 0.8205, 'NPV': 0.5284, 'support': 1349}, 'marco avg': {'f1-score': 0.3633, 'precision': 0.4139, 'recall': 0.3681, 'specificity': 0.7338, 'NPV': 0.7145, 'support': 2324}, 'weighted avg': {'f1-score': 0.5162, 'precision': 0.6195, 'recall': 0.463, 'specificity': 0.7384, 'NPV': 0.5953, 'support': 2324}, 'accuracy': 0.463}
# ibc
# [[ 79 110  12]
#  [170 797 249]
#  [ 74 717 889]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.8516 | 0.0006 |   0.851   |   0.8522  |
# |   1   | 0.6448 | 0.0007 |   0.6442  |   0.6455  |
# |   2   | 0.7668 | 0.0005 |   0.7663  |   0.7673  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.3015  |   0.2446  | 0.393  |    0.9157   | 0.956  |   201   |
# |      1       |  0.5613  |   0.4908  | 0.6554 |    0.5603   | 0.7155 |   1216  |
# |      2       |  0.6283  |   0.773   | 0.5292 |    0.8158   | 0.5937 |   1680  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.5699 |   3097  |
# |  marco avg   |  0.497   |   0.5028  | 0.5259 |    0.764    | 0.7551 |   3097  |
# | weighted avg |  0.5808  |   0.6279  | 0.5699 |    0.722    | 0.6651 |   3097  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.8516, 'auc-ci': 0.0006, 'auc-lower': 0.851, 'auc-upper': 0.8522, 'f1-score': 0.3015, 'precision': 0.2446, 'recall': 0.393, 'specificity': 0.9157, 'NPV': 0.956, 'support': 201}, '1': {'auc': 0.6448, 'auc-ci': 0.0007, 'auc-lower': 0.6442, 'auc-upper': 0.6455, 'f1-score': 0.5613, 'precision': 0.4908, 'recall': 0.6554, 'specificity': 0.5603, 'NPV': 0.7155, 'support': 1216}, '2': {'auc': 0.7668, 'auc-ci': 0.0005, 'auc-lower': 0.7663, 'auc-upper': 0.7673, 'f1-score': 0.6283, 'precision': 0.773, 'recall': 0.5292, 'specificity': 0.8158, 'NPV': 0.5937, 'support': 1680}, 'marco avg': {'f1-score': 0.497, 'precision': 0.5028, 'recall': 0.5259, 'specificity': 0.764, 'NPV': 0.7551, 'support': 3097}, 'weighted avg': {'f1-score': 0.5808, 'precision': 0.6279, 'recall': 0.5699, 'specificity': 0.722, 'NPV': 0.6651, 'support': 3097}, 'accuracy': 0.5699}

# %%
shandaer_root = pathlib.Path('/mnt/hd0/project_large_files/bcacad/patches/shandaer_test')
shandaer_save_root = pathlib.Path('/mnt/hd0/project_large_files/bcacad/patches/shandaer_test/test_swin_ibot_features')
X, Y = get_X_Y(shandaer_root, shandaer_save_root, phases=['test'])

for task in tasks:
    model = mclf
    preds = model.predict(np.array(X[task]['test']))
    probs = model.predict_proba(np.array(X[task]['test']))
    probs = np.array(probs)
    if task == 'type':
        preds = preds[:, 0]
        probs = probs[0, :]
    else:
        preds = preds[:, 1]
        probs = probs[1, :]
    labels = np.array(Y[task]['test'])
    print(task)
    cm = confusion_matrix(labels, preds)
    plot_confusion_matrix(cm, class_names[task])
    print(report(labels, preds, probs, class_names[task]))
# Out:
# Processing test: 100%|██████████| 4545/4545 [17:49<00:00,  4.25it/s]
# type
# /home/yuxin/miniconda3/envs/histosslscaling/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /home/yuxin/miniconda3/envs/histosslscaling/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/yuxin/miniconda3/envs/histosslscaling/lib/python3.8/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/yuxin/miniconda3/envs/histosslscaling/lib/python3.8/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/yuxin/miniconda3/envs/histosslscaling/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/yuxin/miniconda3/envs/histosslscaling/lib/python3.8/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/yuxin/miniconda3/envs/histosslscaling/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [[   0    0    0]
#  [ 222 2133  141]
#  [  20  435 1594]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   |  nan   |  nan   |    nan    |    nan    |
# |   1   | 0.9005 | 0.0003 |   0.9003  |   0.9008  |
# |   2   | 0.9424 | 0.0002 |   0.9422  |   0.9426  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |   0.0    |    0.0    |  0.0   |    0.9468   |  1.0   |    0    |
# |      1       |  0.8424  |   0.8306  | 0.8546 |    0.7877   | 0.8164 |   2496  |
# |      2       |  0.8425  |   0.9187  | 0.7779 |    0.9435   | 0.8381 |   2049  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             |  0.82  |   4545  |
# |  marco avg   |  0.5616  |   0.5831  | 0.5442 |    0.8927   | 0.8848 |   4545  |
# | weighted avg |  0.8425  |   0.8703  |  0.82  |    0.8579   | 0.8262 |   4545  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': nan, 'auc-ci': nan, 'auc-lower': nan, 'auc-upper': nan, 'f1-score': 0.0, 'precision': 0.0, 'recall': 0.0, 'specificity': 0.9468, 'NPV': 1.0, 'support': 0}, '1': {'auc': 0.9005, 'auc-ci': 0.0003, 'auc-lower': 0.9003, 'auc-upper': 0.9008, 'f1-score': 0.8424, 'precision': 0.8306, 'recall': 0.8546, 'specificity': 0.7877, 'NPV': 0.8164, 'support': 2496}, '2': {'auc': 0.9424, 'auc-ci': 0.0002, 'auc-lower': 0.9422, 'auc-upper': 0.9426, 'f1-score': 0.8425, 'precision': 0.9187, 'recall': 0.7779, 'specificity': 0.9435, 'NPV': 0.8381, 'support': 2049}, 'marco avg': {'f1-score': 0.5616, 'precision': 0.5831, 'recall': 0.5442, 'specificity': 0.8927, 'NPV': 0.8848, 'support': 4545}, 'weighted avg': {'f1-score': 0.8425, 'precision': 0.8703, 'recall': 0.82, 'specificity': 0.8579, 'NPV': 0.8262, 'support': 4545}, 'accuracy': 0.82}
# nonibc
# [[ 95 135  18]
#  [248 650 244]
#  [146 527 433]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.7327 | 0.0009 |   0.7318  |   0.7335  |
# |   1   | 0.5487 | 0.0007 |   0.548   |   0.5494  |
# |   2   | 0.6477 | 0.0007 |   0.6471  |   0.6484  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.2578  |   0.1943  | 0.3831 |    0.8247   | 0.9238 |   248   |
# |      1       |  0.5297  |   0.4954  | 0.5692 |    0.5111   | 0.5845 |   1142  |
# |      2       |  0.4808  |   0.623   | 0.3915 |    0.8115   | 0.6263 |   1106  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.472  |   2496  |
# |  marco avg   |  0.4228  |   0.4376  | 0.4479 |    0.7158   | 0.7115 |   2496  |
# | weighted avg |  0.4811  |   0.522   | 0.472  |    0.6754   | 0.6367 |   2496  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.7327, 'auc-ci': 0.0009, 'auc-lower': 0.7318, 'auc-upper': 0.7335, 'f1-score': 0.2578, 'precision': 0.1943, 'recall': 0.3831, 'specificity': 0.8247, 'NPV': 0.9238, 'support': 248}, '1': {'auc': 0.5487, 'auc-ci': 0.0007, 'auc-lower': 0.548, 'auc-upper': 0.5494, 'f1-score': 0.5297, 'precision': 0.4954, 'recall': 0.5692, 'specificity': 0.5111, 'NPV': 0.5845, 'support': 1142}, '2': {'auc': 0.6477, 'auc-ci': 0.0007, 'auc-lower': 0.6471, 'auc-upper': 0.6484, 'f1-score': 0.4808, 'precision': 0.623, 'recall': 0.3915, 'specificity': 0.8115, 'NPV': 0.6263, 'support': 1106}, 'marco avg': {'f1-score': 0.4228, 'precision': 0.4376, 'recall': 0.4479, 'specificity': 0.7158, 'NPV': 0.7115, 'support': 2496}, 'weighted avg': {'f1-score': 0.4811, 'precision': 0.522, 'recall': 0.472, 'specificity': 0.6754, 'NPV': 0.6367, 'support': 2496}, 'accuracy': 0.472}
# ibc
# [[ 57  31   3]
#  [ 99 609 156]
#  [ 34 615 445]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.9119 | 0.0009 |   0.911   |   0.9127  |
# |   1   | 0.6019 | 0.0007 |   0.6012  |   0.6027  |
# |   2   | 0.6907 | 0.0007 |    0.69   |   0.6914  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.4057  |    0.3    | 0.6264 |    0.9321   | 0.9817 |    91   |
# |      1       |  0.5748  |   0.4853  | 0.7049 |    0.4549   | 0.6788 |   864   |
# |      2       |  0.5241  |   0.7368  | 0.4068 |    0.8335   | 0.5509 |   1094  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.5422 |   2049  |
# |  marco avg   |  0.5015  |   0.5073  | 0.5793 |    0.7401   | 0.7371 |   2049  |
# | weighted avg |  0.5402  |   0.6113  | 0.5422 |    0.6782   | 0.624  |   2049  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.9119, 'auc-ci': 0.0009, 'auc-lower': 0.911, 'auc-upper': 0.9127, 'f1-score': 0.4057, 'precision': 0.3, 'recall': 0.6264, 'specificity': 0.9321, 'NPV': 0.9817, 'support': 91}, '1': {'auc': 0.6019, 'auc-ci': 0.0007, 'auc-lower': 0.6012, 'auc-upper': 0.6027, 'f1-score': 0.5748, 'precision': 0.4853, 'recall': 0.7049, 'specificity': 0.4549, 'NPV': 0.6788, 'support': 864}, '2': {'auc': 0.6907, 'auc-ci': 0.0007, 'auc-lower': 0.69, 'auc-upper': 0.6914, 'f1-score': 0.5241, 'precision': 0.7368, 'recall': 0.4068, 'specificity': 0.8335, 'NPV': 0.5509, 'support': 1094}, 'marco avg': {'f1-score': 0.5015, 'precision': 0.5073, 'recall': 0.5793, 'specificity': 0.7401, 'NPV': 0.7371, 'support': 2049}, 'weighted avg': {'f1-score': 0.5402, 'precision': 0.6113, 'recall': 0.5422, 'specificity': 0.6782, 'NPV': 0.624, 'support': 2049}, 'accuracy': 0.5422}

# %%
apght_root = pathlib.Path('/mnt/hd0/project_large_files/bcacad/patches/2017_Agios_Pavlos_patch')
apght_save_root = pathlib.Path('/mnt/hd0/project_large_files/bcacad/patches/2017_Agios_Pavlos_patch_pretrian_ssl_features')
X, Y = get_X_Y(apght_root, apght_root, phases=['test'])

for task in ['ibc']:
    model = mclf
    preds = model.predict(np.array(X[task]['test']))
    probs = model.predict_proba(np.array(X[task]['test']))
    probs = np.array(probs)
    if task == 'type':
        preds = preds[:, 0]
        probs = probs[0, :]
    else:
        preds = preds[:, 1]
        probs = probs[1, :]
    labels = np.array(Y[task]['test'])
    print(task)
    cm = confusion_matrix(labels, preds)
    plot_confusion_matrix(cm, class_names[task])
    print(report(labels, preds, probs, class_names[task]))
# Out:
# Processing test:   0%|          | 0/300 [00:00<?, ?it/s]
# Processing test: 100%|██████████| 300/300 [00:06<00:00, 48.96it/s]
# ibc
# [[69 38  0]
#  [65 37  0]
#  [ 7 67 17]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.694  | 0.0019 |   0.6921  |   0.6959  |
# |   1   | 0.418  | 0.0021 |   0.4159  |    0.42   |
# |   2   | 0.7998 | 0.0017 |   0.7982  |   0.8015  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.5565  |   0.4894  | 0.6449 |    0.6269   | 0.761  |   107   |
# |      1       |  0.3033  |   0.2606  | 0.3627 |    0.4697   | 0.5886 |   102   |
# |      2       |  0.3148  |    1.0    | 0.1868 |     1.0     | 0.7385 |    91   |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             |  0.41  |   300   |
# |  marco avg   |  0.3915  |   0.5833  | 0.3981 |    0.6989   | 0.696  |   300   |
# | weighted avg |  0.3971  |   0.5665  |  0.41  |    0.6866   | 0.6956 |   300   |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.694, 'auc-ci': 0.0019, 'auc-lower': 0.6921, 'auc-upper': 0.6959, 'f1-score': 0.5565, 'precision': 0.4894, 'recall': 0.6449, 'specificity': 0.6269, 'NPV': 0.761, 'support': 107}, '1': {'auc': 0.418, 'auc-ci': 0.0021, 'auc-lower': 0.4159, 'auc-upper': 0.42, 'f1-score': 0.3033, 'precision': 0.2606, 'recall': 0.3627, 'specificity': 0.4697, 'NPV': 0.5886, 'support': 102}, '2': {'auc': 0.7998, 'auc-ci': 0.0017, 'auc-lower': 0.7982, 'auc-upper': 0.8015, 'f1-score': 0.3148, 'precision': 1.0, 'recall': 0.1868, 'specificity': 1.0, 'NPV': 0.7385, 'support': 91}, 'marco avg': {'f1-score': 0.3915, 'precision': 0.5833, 'recall': 0.3981, 'specificity': 0.6989, 'NPV': 0.696, 'support': 300}, 'weighted avg': {'f1-score': 0.3971, 'precision': 0.5665, 'recall': 0.41, 'specificity': 0.6866, 'NPV': 0.6956, 'support': 300}, 'accuracy': 0.41}

# %%
def get_Bracs_X_Y(data_root, save_root, phases=['test']):
    data_root = pathlib.Path(data_root)
    save_root = pathlib.Path(save_root)
    X={}
    Y={}
    for task in ['type']:
        X[task] = {}
        Y[task] = {}
        for phase in phases:
            X[task][phase] = []
            Y[task][phase] = []

    for phase in phases:
        tile_paths = []
        for l in ['0_N', '5_DCIS', '6_IC']:
            tile_paths.extend(list((data_root).glob(f'*/{l}/*.png')))
        for path in tqdm(tile_paths, desc=f'Processing {phase}'):
            save_path = save_root / path.parent.name / path.name /f'{path.stem}.npy' 
            if save_path.exists():
                feature = np.load(save_path)
            else:
                save_path.parent.mkdir(exist_ok=True, parents=True)
                im = Image.open(path)
                tensor = data_trans(im)
                batch = tensor.unsqueeze(0)
                batch = batch.to(device)
                feature = ibot_base_pancancer(batch).detach().cpu().numpy()
                feature = feature.flatten()
                np.save(save_path, feature)

            if path.parent.name == '0_N':
                type = 0
            elif path.parent.name == '5_DCIS':
                type = 1
            elif path.parent.name == '6_IC':
                type = 2
            
            X['type'][phase].append(feature)
            Y['type'][phase].append(type)

    return X, Y

# %%
X,Y = get_Bracs_X_Y('/mnt/hd0/project_large_files/bcacad/patches/bracs_patch/latest_version_patch', '/mnt/hd0/project_large_files/bcacad/patches/bracs_patch/latest_version_patch_pre_ssl_features', phases=['test'])
# Out:
# Processing test: 100%|██████████| 10094/10094 [04:51<00:00, 34.62it/s]

# %%
for task in ['type']:
    model = mclf
    preds = model.predict(np.array(X[task]['test']))
    probs = model.predict_proba(np.array(X[task]['test']))
    probs = np.array(probs)
    if task == 'type':
        preds = preds[:, 0]
        probs = probs[0, :]
    else:
        preds = preds[:, 1]
        probs = probs[1, :]
    labels = np.array(Y[task]['test'])
    print(task)
    cm = confusion_matrix(labels, preds)
    plot_confusion_matrix(cm, class_names[task])
    print(report(labels, preds, probs, class_names[task]))
# Out:
# type
# [[1329  338    5]
#  [  32 3526   64]
#  [  49 1300 3451]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.991  |  0.0   |   0.991   |   0.9911  |
# |   1   | 0.9338 | 0.0001 |   0.9336  |   0.9339  |
# |   2   | 0.9431 | 0.0001 |   0.943   |   0.9433  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.8624  |   0.9426  | 0.7949 |    0.9904   | 0.9605 |   1672  |
# |      1       |  0.8026  |   0.6828  | 0.9735 |    0.7469   | 0.9805 |   3622  |
# |      2       |  0.8296  |   0.9804  | 0.719  |    0.987    | 0.7948 |   4800  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.8229 |  10094  |
# |  marco avg   |  0.8315  |   0.8686  | 0.8291 |    0.9081   | 0.9119 |  10094  |
# | weighted avg |  0.8253  |   0.8673  | 0.8229 |    0.9014   | 0.8889 |  10094  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.991, 'auc-ci': 0.0, 'auc-lower': 0.991, 'auc-upper': 0.9911, 'f1-score': 0.8624, 'precision': 0.9426, 'recall': 0.7949, 'specificity': 0.9904, 'NPV': 0.9605, 'support': 1672}, '1': {'auc': 0.9338, 'auc-ci': 0.0001, 'auc-lower': 0.9336, 'auc-upper': 0.9339, 'f1-score': 0.8026, 'precision': 0.6828, 'recall': 0.9735, 'specificity': 0.7469, 'NPV': 0.9805, 'support': 3622}, '2': {'auc': 0.9431, 'auc-ci': 0.0001, 'auc-lower': 0.943, 'auc-upper': 0.9433, 'f1-score': 0.8296, 'precision': 0.9804, 'recall': 0.719, 'specificity': 0.987, 'NPV': 0.7948, 'support': 4800}, 'marco avg': {'f1-score': 0.8315, 'precision': 0.8686, 'recall': 0.8291, 'specificity': 0.9081, 'NPV': 0.9119, 'support': 10094}, 'weighted avg': {'f1-score': 0.8253, 'precision': 0.8673, 'recall': 0.8229, 'specificity': 0.9014, 'NPV': 0.8889, 'support': 10094}, 'accuracy': 0.8229}

# %%
def get_BACH_X_Y(data_root, save_root, phases=['test']):
    data_root = pathlib.Path(data_root)
    save_root = pathlib.Path(save_root)
    X={}
    Y={}
    for task in ['type']:
        X[task] = {}
        Y[task] = {}
        for phase in phases:
            X[task][phase] = []
            Y[task][phase] = []

    for phase in phases:
        tile_paths = []
        for l in ['Normal', 'InSitu', 'Invasive']:
            tile_paths.extend(list((data_root/l).glob('**/*.tif')))
        for path in tqdm(tile_paths, desc=f'Processing {phase}'):
            save_path = save_root / path.parent.name / path.name /f'{path.stem}.npy' 
            if save_path.exists():
                feature = np.load(save_path)
            else:
                save_path.parent.mkdir(exist_ok=True, parents=True)
                im = Image.open(path)
                tensor = data_trans(im)
                batch = tensor.unsqueeze(0)
                batch = batch.to(device)
                feature = ibot_base_pancancer(batch).detach().cpu().numpy()
                feature = feature.flatten()
                np.save(save_path, feature)

            if path.parent.name == 'Normal':
                type = 0
            elif path.parent.name == 'InSitu':
                type = 1
            elif path.parent.name == 'Invasive':
                type = 2
            
            X['type'][phase].append(feature)
            Y['type'][phase].append(type)

    return X, Y

# %%
X,Y = get_BACH_X_Y('/mnt/hd0/project_large_files/bcacad/patches/bach_patch/Photos_patch_tif', '/mnt/hd0/project_large_files/bcacad/patches/bach_patch/Photos_patch_tif_pre_ssl_features', phases=['test'])
# Out:
# Processing test: 100%|██████████| 1200/1200 [00:30<00:00, 39.57it/s]

# %%
for task in ['type']:
    model = mclf
    preds = model.predict(np.array(X[task]['test']))
    probs = model.predict_proba(np.array(X[task]['test']))
    probs = np.array(probs)
    if task == 'type':
        preds = preds[:, 0]
        probs = probs[0, :]
    else:
        preds = preds[:, 1]
        probs = probs[1, :]
    labels = np.array(Y[task]['test'])
    print(task)
    cm = confusion_matrix(labels, preds)
    plot_confusion_matrix(cm, class_names[task])
    print(report(labels, preds, probs, class_names[task]))
# Out:
# type
# [[281 112   7]
#  [ 25 337  38]
#  [  8 116 276]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.9569 | 0.0003 |   0.9566  |   0.9573  |
# |   1   | 0.8584 | 0.0007 |   0.8577  |   0.8591  |
# |   2   | 0.9135 | 0.0006 |   0.9129  |   0.9142  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.7871  |   0.8949  | 0.7025 |    0.9588   | 0.8657 |   400   |
# |      1       |  0.6984  |   0.5965  | 0.8425 |    0.715    | 0.9008 |   400   |
# |      2       |  0.7656  |   0.8598  |  0.69  |    0.9438   | 0.8589 |   400   |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.745  |   1200  |
# |  marco avg   |  0.7504  |   0.7837  | 0.745  |    0.8725   | 0.8751 |   1200  |
# | weighted avg |  0.7504  |   0.7837  | 0.745  |    0.8725   | 0.8751 |   1200  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.9569, 'auc-ci': 0.0003, 'auc-lower': 0.9566, 'auc-upper': 0.9573, 'f1-score': 0.7871, 'precision': 0.8949, 'recall': 0.7025, 'specificity': 0.9588, 'NPV': 0.8657, 'support': 400}, '1': {'auc': 0.8584, 'auc-ci': 0.0007, 'auc-lower': 0.8577, 'auc-upper': 0.8591, 'f1-score': 0.6984, 'precision': 0.5965, 'recall': 0.8425, 'specificity': 0.715, 'NPV': 0.9008, 'support': 400}, '2': {'auc': 0.9135, 'auc-ci': 0.0006, 'auc-lower': 0.9129, 'auc-upper': 0.9142, 'f1-score': 0.7656, 'precision': 0.8598, 'recall': 0.69, 'specificity': 0.9438, 'NPV': 0.8589, 'support': 400}, 'marco avg': {'f1-score': 0.7504, 'precision': 0.7837, 'recall': 0.745, 'specificity': 0.8725, 'NPV': 0.8751, 'support': 1200}, 'weighted avg': {'f1-score': 0.7504, 'precision': 0.7837, 'recall': 0.745, 'specificity': 0.8725, 'NPV': 0.8751, 'support': 1200}, 'accuracy': 0.745}

# %%
def get_BCNB_X_Y(data_root, save_root, phases=['test']):
    X={}
    Y={}
    for task in ['ibc']:
        X[task] = {}
        Y[task] = {}
        for phase in phases:
            X[task][phase] = []
            Y[task][phase] = []

    for phase in phases:
        phase_root = data_root
        tile_paths = list(phase_root.glob('**/*/*.jpg'))
        for path in tqdm(tile_paths, desc=f'Processing {phase}'):
            save_path = save_root / phase / path.parent.parent.name /f'{path.stem}.npy' 
            if save_path.exists():
                feature = np.load(save_path)
            else:
                save_path.parent.mkdir(exist_ok=True, parents=True)
                im = Image.open(path)
                tensor = data_trans(im)
                batch = tensor.unsqueeze(0)
                batch = batch.to(device)
                feature = ibot_base_pancancer(batch).detach().cpu().numpy()
                feature = feature.flatten()
                np.save(save_path, feature)

            grade = int(path.parent.parent.name.split('-')[-1])-1
            

            X['ibc'][phase].append(feature)
            Y['ibc'][phase].append(grade)
    return X, Y

# %%
bcnb_root = pathlib.Path('/mnt/hd0/project_large_files/bcacad/patches/bcnb/patches_test_10x')
bcnb_save_root = pathlib.Path('/mnt/hd0/project_large_files/bcacad/patches/bcnb/patches_test_10x_pre_ssl_features')
X, Y = get_BCNB_X_Y(bcnb_root, bcnb_save_root, phases=['test'])
# Out:
# Processing test: 100%|██████████| 9686/9686 [00:03<00:00, 2807.31it/s]

# %%
Y['ibc']['test'] = np.array(Y['ibc']['test'])
np.unique(Y['ibc']['test'], return_counts=True)
# Out:
# (array([0, 1, 2]), array([ 355, 5704, 3627]))

# %%
from metrics3 import report
for task in ['ibc']:
    model = mclf
    preds = model.predict(np.array(X[task]['test']))
    probs = model.predict_proba(np.array(X[task]['test']))
    probs = np.array(probs)
    if task == 'type':
        preds = preds[:, 0]
        probs = probs[0, :]
    else:
        preds = preds[:, 1]
        probs = probs[1, :]
    labels = np.array(Y[task]['test'])
    print(task)
    cm = confusion_matrix(labels, preds)
    plot_confusion_matrix(cm, class_names[task])
    print(report(labels, preds, probs, class_names[task]))
# Out:
# ibc
# [[ 212  125   18]
#  [2286 2606  812]
#  [1040 1884  703]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.6797 | 0.0008 |   0.6789  |   0.6805  |
# |   1   | 0.4662 | 0.0004 |   0.4659  |   0.4666  |
# |   2   | 0.5657 | 0.0004 |   0.5653  |   0.5661  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.1089  |   0.0599  | 0.5972 |    0.6436   | 0.9767 |   355   |
# |      1       |  0.5051  |   0.5647  | 0.4569 |    0.4955   | 0.3891 |   5704  |
# |      2       |  0.2725  |   0.4586  | 0.1938 |    0.863    | 0.6414 |   3627  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.3635 |   9686  |
# |  marco avg   |  0.2955  |   0.3611  | 0.416  |    0.6673   | 0.6691 |   9686  |
# | weighted avg |  0.4035  |   0.5064  | 0.3635 |    0.6385   | 0.5051 |   9686  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.6797, 'auc-ci': 0.0008, 'auc-lower': 0.6789, 'auc-upper': 0.6805, 'f1-score': 0.1089, 'precision': 0.0599, 'recall': 0.5972, 'specificity': 0.6436, 'NPV': 0.9767, 'support': 355}, '1': {'auc': 0.4662, 'auc-ci': 0.0004, 'auc-lower': 0.4659, 'auc-upper': 0.4666, 'f1-score': 0.5051, 'precision': 0.5647, 'recall': 0.4569, 'specificity': 0.4955, 'NPV': 0.3891, 'support': 5704}, '2': {'auc': 0.5657, 'auc-ci': 0.0004, 'auc-lower': 0.5653, 'auc-upper': 0.5661, 'f1-score': 0.2725, 'precision': 0.4586, 'recall': 0.1938, 'specificity': 0.863, 'NPV': 0.6414, 'support': 3627}, 'marco avg': {'f1-score': 0.2955, 'precision': 0.3611, 'recall': 0.416, 'specificity': 0.6673, 'NPV': 0.6691, 'support': 9686}, 'weighted avg': {'f1-score': 0.4035, 'precision': 0.5064, 'recall': 0.3635, 'specificity': 0.6385, 'NPV': 0.5051, 'support': 9686}, 'accuracy': 0.3635}

# %%
a= report(labels, preds, probs, class_names[task])
# Out:
# [[ 212  125   18]
#  [2286 2606  812]
#  [1040 1884  703]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.6797 | 0.0008 |   0.6789  |   0.6805  |
# |   1   | 0.4662 | 0.0004 |   0.4659  |   0.4666  |
# |   2   | 0.5657 | 0.0004 |   0.5653  |   0.5661  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.1089  |   0.0599  | 0.5972 |    0.6436   | 0.9767 |   355   |
# |      1       |  0.5051  |   0.5647  | 0.4569 |    0.4955   | 0.3891 |   5704  |
# |      2       |  0.2725  |   0.4586  | 0.1938 |    0.863    | 0.6414 |   3627  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.3635 |   9686  |
# |  marco avg   |  0.2955  |   0.3611  | 0.416  |    0.6673   | 0.6691 |   9686  |
# | weighted avg |  0.4035  |   0.5064  | 0.3635 |    0.6385   | 0.5051 |   9686  |
# +--------------+----------+-----------+--------+-------------+--------+---------+

# %%
a['0']['auc']
# Out:
# 0.6797
