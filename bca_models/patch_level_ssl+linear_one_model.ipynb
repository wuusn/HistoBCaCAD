# %%
from PIL import Image
from rl_benchmarks.models import iBOTViT
from openslide import open_slide
from openslide.deepzoom import DeepZoomGenerator
import pathlib
from tqdm import tqdm
from PIL import Image
import numpy as np
Image.MAX_IMAGE_PIXELS = None
from torchvision import transforms
import torch
from torch.utils.data import Dataset
import os
from multiprocessing import Pool
import umap
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from rl_benchmarks.utils.linear_evaluation import get_binary_class_metrics, get_bootstrapped_metrics, dict_to_dataframe
import umap.plot
# Out:
# /home/yuxin/miniconda3/envs/histosslscaling/lib/python3.8/site-packages/umap/plot.py:203: NumbaDeprecationWarning: The keyword argument 'nopython=False' was supplied. From Numba 0.59.0 the default is being changed to True and use of 'nopython=False' will raise a warning as the argument will have no effect. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit(nopython=False)

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
weights_path = '/home/yuxin/Downloads/ibot_vit_base_pancan.pth'
ibot_base_pancancer = iBOTViT(architecture="vit_base_pancan", encoder="student", weights_path=weights_path).to(device)
# Out:
# 2023-12-30 14:40:22.448 | INFO     | rl_benchmarks.models.feature_extractors.ibot_vit:__init__:78 - Pretrained weights found at /home/yuxin/Downloads/ibot_vit_base_pancan.pth and loaded with msg: _IncompatibleKeys(missing_keys=[], unexpected_keys=['masked_embed', 'head.mlp.0.weight', 'head.mlp.0.bias', 'head.mlp.2.weight', 'head.mlp.2.bias', 'head.mlp.4.weight', 'head.mlp.4.bias', 'head.last_layer.weight_g', 'head.last_layer.weight_v', 'head.last_layer2.weight_g', 'head.last_layer2.weight_v'])

# %%
patch_size = 224
data_root = pathlib.Path('/mnt/hd0/ssd/SUQH_10x336')
# model_root = pathlib.Path('/home/yuxin/ssd_data/SUQH_10x_tiles/model_balanced')
test_root = pathlib.Path('/home/yuxin/ssd_data/SUQH_10x336/test')
phases = ['model', 'test']
# save_root = pathlib.Path('/mnt/hd0/project_large_files/bcacad/pretrain_ssl_SUQH_10x336_tiles_model_balanced_features')
save_root = pathlib.Path('/mnt/hd0/project_large_files/bcacad/finetune_ibot')
save_root.mkdir(exist_ok=True)
data_trans = transforms.Compose([
                                transforms.CenterCrop(336),
                                transforms.Resize(patch_size),
                                ibot_base_pancancer.transform,
                                ])

# %%
def get_type_grade(path):
    type_grade = path.parent.name
    if type_grade == 'normal':
        return 0,0
    elif type_grade == 'tis-1':
        return 1,0
    elif type_grade == 'tis-2':
        return 1,1
    elif type_grade == 'tis-3':
        return 1,2
    elif type_grade == 'it-1':
        return 2,0
    elif type_grade == 'it-2':
        return 2,1
    elif type_grade == 'it-3':
        return 2,2

# %%
phase_roots = {
    'model': data_root,
    'test': test_root

}
X = {
    'model': [],
    'test': []
}
Y = {
    'model': [],
    'test': []
}
for phase in phases:
    phase_root = phase_roots[phase]
    if phase == 'model':
        tile_paths = list(phase_root.glob('**/*.png'))
    else:
        tile_paths = list(phase_root.glob('**/*.jpg'))
    for path in tqdm(tile_paths, desc=f'Processing {phase}'):
        save_path = save_root / phase / path.parent.name /f'{path.stem}.npy' 
        if save_path.exists():
            feature = np.load(save_path)
        else:
            save_path.parent.mkdir(exist_ok=True, parents=True)
            im = Image.open(path)
            tensor = data_trans(im)
            batch = tensor.unsqueeze(0)
            batch = batch.to(device)
            feature = ibot_base_pancancer(batch).detach().cpu().numpy()
            feature = feature.flatten()
            np.save(save_path, feature)
        X[phase].append(feature)
        type, grade = get_type_grade(path)
        Y[phase].append([type, grade])
# Out:
# Processing model:   0%|          | 0/3396 [00:00<?, ?it/s]
# Processing model: 100%|██████████| 3396/3396 [00:23<00:00, 147.36it/s]
# Processing test: 100%|██████████| 47330/47330 [05:00<00:00, 157.62it/s]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

def plot_confusion_matrix(confusion_matrix, labels):
    fig, ax = plt.subplots(figsize=(8, 6))
    sns.heatmap(confusion_matrix, annot=True, fmt="d", cmap="Blues", cbar=False, ax=ax)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')
    ax.set_xticklabels(labels)
    ax.set_yticklabels(labels)
    plt.title('Confusion Matrix')
    plt.show()

# %%
def get_metrics(labels, scores, class_names, phase='test'):
    n_resamples = 1000
    confidence_level = 0.95

    binary_metrics = {phase:get_binary_class_metrics(labels, scores)}
    bootstrapped_metrics = {phase: get_bootstrapped_metrics(
        labels, scores, n_resamples=n_resamples, confidence_level=confidence_level
    )}

    results_dict = {
        "binary": binary_metrics,
        "bootstrap": bootstrapped_metrics,
    }
    
    results = dict_to_dataframe(
        results_dict, metrics=["auc", "acc", "f1"], class_names=class_names
    )
    return results

# %%
import sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.multioutput import MultiOutputClassifier
import numpy as np

clf = sklearn.linear_model.SGDClassifier(
                loss="log_loss",
                penalty="l2",
                learning_rate="adaptive",
                eta0=1e-4,
                n_jobs=8,
                early_stopping=False,
                random_state=2023,
            )
mclf = MultiOutputClassifier(clf, n_jobs=10)

# %%
mclf.fit(np.array(X['model']), np.array(Y['model']))
# Out:
# MultiOutputClassifier(estimator=SGDClassifier(eta0=0.0001,
#                                               learning_rate='adaptive',
#                                               loss='log_loss', n_jobs=8,
#                                               random_state=2023),
#                       n_jobs=10)

# %%
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.multioutput import MultiOutputClassifier
# import numpy as np

# clf = RandomForestClassifier(random_state=2023)
# mclf = MultiOutputClassifier(clf, n_jobs=10)
# mclf.fit(np.array(X['train']+X['val']), np.array(Y['train']+Y['val']))

# %%
# SUQH Type
from metrics3 import report

y_pred = mclf.predict(np.array(X['test']))
y_prob = np.array(mclf.predict_proba(np.array(X['test'])))
y_true = np.array(Y['test'])
tasks = ['type', 'grade']
class_names = {
    'type': ['Normal', 'nonIBC', 'IBC'],
    'grade': ['Low', 'Median', 'High']
}

type_y_pred = y_pred[:, 0]
type_y_prob = y_prob[0, :]
type_y_true = y_true[:, 0]
type_cm = confusion_matrix(type_y_true, type_y_pred)
plot_confusion_matrix(type_cm, class_names['type'])
print(report(type_y_true, type_y_pred, type_y_prob, class_names['type']))
# Out:
# [[10718  4564  1082]
#  [  264 12962  3525]
#  [   27   858 13330]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.9832 |  0.0   |   0.9831  |   0.9832  |
# |   1   | 0.8933 | 0.0001 |   0.8932  |   0.8934  |
# |   2   | 0.9694 |  0.0   |   0.9694  |   0.9695  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.7831  |   0.9736  | 0.655  |    0.9906   | 0.8446 |  16364  |
# |      1       |  0.7378  |   0.7051  | 0.7738 |    0.8227   | 0.8691 |  16751  |
# |      2       |  0.8292  |   0.7432  | 0.9377 |    0.8609   | 0.9699 |  14215  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.782  |  47330  |
# |  marco avg   |  0.7834  |   0.8073  | 0.7888 |    0.8914   | 0.8945 |  47330  |
# | weighted avg |  0.7809  |   0.8093  | 0.782  |    0.8922   | 0.8909 |  47330  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.9832, 'auc-ci': 0.0, 'auc-lower': 0.9831, 'auc-upper': 0.9832, 'f1-score': 0.7831, 'precision': 0.9736, 'recall': 0.655, 'specificity': 0.9906, 'NPV': 0.8446, 'support': 16364}, '1': {'auc': 0.8933, 'auc-ci': 0.0001, 'auc-lower': 0.8932, 'auc-upper': 0.8934, 'f1-score': 0.7378, 'precision': 0.7051, 'recall': 0.7738, 'specificity': 0.8227, 'NPV': 0.8691, 'support': 16751}, '2': {'auc': 0.9694, 'auc-ci': 0.0, 'auc-lower': 0.9694, 'auc-upper': 0.9695, 'f1-score': 0.8292, 'precision': 0.7432, 'recall': 0.9377, 'specificity': 0.8609, 'NPV': 0.9699, 'support': 14215}, 'marco avg': {'f1-score': 0.7834, 'precision': 0.8073, 'recall': 0.7888, 'specificity': 0.8914, 'NPV': 0.8945, 'support': 47330}, 'weighted avg': {'f1-score': 0.7809, 'precision': 0.8093, 'recall': 0.782, 'specificity': 0.8922, 'NPV': 0.8909, 'support': 47330}, 'accuracy': 0.782}

# %%
# SUQH nonIBC
tumor_idx = np.where(type_y_true == 1)[0]
grade_y_pred = y_pred[tumor_idx, 1]
grade_y_prob = y_prob[1, tumor_idx]
grade_y_true = y_true[tumor_idx, 1]
grade_cm = confusion_matrix(grade_y_true, grade_y_pred)
plot_confusion_matrix(grade_cm, class_names['grade'])
print(report(grade_y_true, grade_y_pred, grade_y_prob, class_names['grade']))
# Out:
# [[ 974  432  521]
#  [1492 1692 3891]
#  [ 311  675 6763]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.7549 | 0.0004 |   0.7546  |   0.7553  |
# |   1   | 0.6145 | 0.0003 |   0.6142  |   0.6147  |
# |   2   | 0.8024 | 0.0002 |   0.8022  |   0.8026  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.4141  |   0.3507  | 0.5054 |    0.8784   | 0.9318 |   1927  |
# |      1       |  0.3427  |   0.6045  | 0.2392 |    0.8856   | 0.6142 |   7075  |
# |      2       |  0.7148  |   0.6052  | 0.8728 |    0.5099   | 0.8232 |   7749  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.5629 |  16751  |
# |  marco avg   |  0.4905  |   0.5201  | 0.5391 |    0.758    | 0.7897 |  16751  |
# | weighted avg |  0.523   |   0.5756  | 0.5629 |    0.711    | 0.7474 |  16751  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.7549, 'auc-ci': 0.0004, 'auc-lower': 0.7546, 'auc-upper': 0.7553, 'f1-score': 0.4141, 'precision': 0.3507, 'recall': 0.5054, 'specificity': 0.8784, 'NPV': 0.9318, 'support': 1927}, '1': {'auc': 0.6145, 'auc-ci': 0.0003, 'auc-lower': 0.6142, 'auc-upper': 0.6147, 'f1-score': 0.3427, 'precision': 0.6045, 'recall': 0.2392, 'specificity': 0.8856, 'NPV': 0.6142, 'support': 7075}, '2': {'auc': 0.8024, 'auc-ci': 0.0002, 'auc-lower': 0.8022, 'auc-upper': 0.8026, 'f1-score': 0.7148, 'precision': 0.6052, 'recall': 0.8728, 'specificity': 0.5099, 'NPV': 0.8232, 'support': 7749}, 'marco avg': {'f1-score': 0.4905, 'precision': 0.5201, 'recall': 0.5391, 'specificity': 0.758, 'NPV': 0.7897, 'support': 16751}, 'weighted avg': {'f1-score': 0.523, 'precision': 0.5756, 'recall': 0.5629, 'specificity': 0.711, 'NPV': 0.7474, 'support': 16751}, 'accuracy': 0.5629}

# %%
# SUQH nonIBC
tumor_idx = np.where(type_y_true == 2)[0]
grade_y_pred = y_pred[tumor_idx, 1]
grade_y_prob = y_prob[1, tumor_idx]
grade_y_true = y_true[tumor_idx, 1]
grade_cm = confusion_matrix(grade_y_true, grade_y_pred)
plot_confusion_matrix(grade_cm, class_names['grade'])
print(report(grade_y_true, grade_y_pred, grade_y_prob, class_names['grade']))
# Out:
# [[ 778  233  224]
#  [1356 2213 5133]
#  [ 119  498 3661]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.8801 | 0.0003 |   0.8798  |   0.8804  |
# |   1   | 0.6354 | 0.0003 |   0.6351  |   0.6357  |
# |   2   | 0.7653 | 0.0003 |   0.765   |   0.7655  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.4461  |   0.3453  |  0.63  |    0.8864   | 0.9618 |   1235  |
# |      1       |   0.38   |   0.7517  | 0.2543 |    0.8674   | 0.4243 |   8702  |
# |      2       |  0.5507  |   0.406   | 0.8558 |    0.4609   | 0.8813 |   4278  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.468  |  14215  |
# |  marco avg   |  0.4589  |   0.501   |  0.58  |    0.7382   | 0.7558 |  14215  |
# | weighted avg |  0.4371  |   0.6123  | 0.468  |    0.7467   | 0.6085 |  14215  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.8801, 'auc-ci': 0.0003, 'auc-lower': 0.8798, 'auc-upper': 0.8804, 'f1-score': 0.4461, 'precision': 0.3453, 'recall': 0.63, 'specificity': 0.8864, 'NPV': 0.9618, 'support': 1235}, '1': {'auc': 0.6354, 'auc-ci': 0.0003, 'auc-lower': 0.6351, 'auc-upper': 0.6357, 'f1-score': 0.38, 'precision': 0.7517, 'recall': 0.2543, 'specificity': 0.8674, 'NPV': 0.4243, 'support': 8702}, '2': {'auc': 0.7653, 'auc-ci': 0.0003, 'auc-lower': 0.765, 'auc-upper': 0.7655, 'f1-score': 0.5507, 'precision': 0.406, 'recall': 0.8558, 'specificity': 0.4609, 'NPV': 0.8813, 'support': 4278}, 'marco avg': {'f1-score': 0.4589, 'precision': 0.501, 'recall': 0.58, 'specificity': 0.7382, 'NPV': 0.7558, 'support': 14215}, 'weighted avg': {'f1-score': 0.4371, 'precision': 0.6123, 'recall': 0.468, 'specificity': 0.7467, 'NPV': 0.6085, 'support': 14215}, 'accuracy': 0.468}

# %%
def get_X_Y(data_root, save_root, phases=['test']):
    X={}
    Y={}
    for task in ['type', 'nonibc', 'ibc']:
        X[task] = {}
        Y[task] = {}
        for phase in phases:
            X[task][phase] = []
            Y[task][phase] = []

    for phase in phases:
        phase_root = data_root / phase
        tile_paths = list(phase_root.glob('**/*.png'))
        for path in tqdm(tile_paths, desc=f'Processing {phase}'):
            save_path = save_root / phase / path.parent.name /f'{path.stem}.npy' 
            if save_path.exists():
                feature = np.load(save_path)
            else:
                save_path.parent.mkdir(exist_ok=True, parents=True)
                im = Image.open(path)
                tensor = data_trans(im)
                batch = tensor.unsqueeze(0)
                batch = batch.to(device)
                feature = ibot_base_pancancer(batch).detach().cpu().numpy()
                feature = feature.flatten()
                np.save(save_path, feature)

            type, grade = get_type_grade(path)
            
            X['type'][phase].append(feature)
            Y['type'][phase].append(type)

            if type == 1:
                X['nonibc'][phase].append(feature)
                Y['nonibc'][phase].append(grade)
            elif type == 2:
                X['ibc'][phase].append(feature)
                Y['ibc'][phase].append(grade)
    return X, Y

# %%
qingdao_root = pathlib.Path('/mnt/hd0/project_large_files/bcacad/patches/qingdao_test')
qingdao_save_root = pathlib.Path('/mnt/hd0/project_large_files/bcacad/patches/qingdao_test/test_ssl_features')
qingdao_X, qingdao_Y = get_X_Y(qingdao_root, qingdao_save_root, phases=['test'])
# Out:
# Processing test: 100%|██████████| 5453/5453 [00:33<00:00, 163.55it/s]

# %%
tasks = ['type', 'nonibc', 'ibc']
class_names = {
    'type': ['Normal', 'nonIBC', 'IBC'],
    'nonibc': ['Low', 'Medium', 'High'],
    'ibc': ['Low', 'Medium', 'High'],
}

# %%
X = qingdao_X
Y = qingdao_Y

for task in tasks:
    model = mclf
    preds = model.predict(np.array(X[task]['test']))
    probs = model.predict_proba(np.array(X[task]['test']))
    probs = np.array(probs)
    if task == 'type':
        preds = preds[:, 0]
        probs = probs[0, :]
    else:
        preds = preds[:, 1]
        probs = probs[1, :]
    labels = np.array(Y[task]['test'])
    print(task)
    cm = confusion_matrix(labels, preds)
    plot_confusion_matrix(cm, class_names[task])
    print(report(labels, preds, probs, class_names[task]))
# Out:
# type
# [[  18   12    2]
#  [ 163 1738  423]
#  [  65  158 2874]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.9521 | 0.0006 |   0.9515  |   0.9527  |
# |   1   | 0.9472 | 0.0002 |   0.947   |   0.9474  |
# |   2   | 0.9479 | 0.0002 |   0.9477  |   0.948   |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.1295  |   0.0732  | 0.5625 |    0.9579   | 0.9973 |    32   |
# |      1       |  0.8214  |   0.9109  | 0.7478 |    0.9457   | 0.8347 |   2324  |
# |      2       |  0.8987  |   0.8712  | 0.928  |    0.8196   | 0.8965 |   3097  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.8491 |   5453  |
# |  marco avg   |  0.6165  |   0.6184  | 0.7461 |    0.9077   | 0.9095 |   5453  |
# | weighted avg |  0.8612  |   0.8834  | 0.8491 |    0.8741   | 0.8707 |   5453  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.9521, 'auc-ci': 0.0006, 'auc-lower': 0.9515, 'auc-upper': 0.9527, 'f1-score': 0.1295, 'precision': 0.0732, 'recall': 0.5625, 'specificity': 0.9579, 'NPV': 0.9973, 'support': 32}, '1': {'auc': 0.9472, 'auc-ci': 0.0002, 'auc-lower': 0.947, 'auc-upper': 0.9474, 'f1-score': 0.8214, 'precision': 0.9109, 'recall': 0.7478, 'specificity': 0.9457, 'NPV': 0.8347, 'support': 2324}, '2': {'auc': 0.9479, 'auc-ci': 0.0002, 'auc-lower': 0.9477, 'auc-upper': 0.948, 'f1-score': 0.8987, 'precision': 0.8712, 'recall': 0.928, 'specificity': 0.8196, 'NPV': 0.8965, 'support': 3097}, 'marco avg': {'f1-score': 0.6165, 'precision': 0.6184, 'recall': 0.7461, 'specificity': 0.9077, 'NPV': 0.9095, 'support': 5453}, 'weighted avg': {'f1-score': 0.8612, 'precision': 0.8834, 'recall': 0.8491, 'specificity': 0.8741, 'NPV': 0.8707, 'support': 5453}, 'accuracy': 0.8491}
# nonibc
# [[  15    8   71]
#  [ 386   76  419]
#  [ 139   66 1144]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.5342 | 0.0015 |   0.5328  |   0.5357  |
# |   1   |  0.5   | 0.0007 |   0.4993  |   0.5008  |
# |   2   | 0.7793 | 0.0006 |   0.7787  |   0.7799  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.0473  |   0.0278  | 0.1596 |    0.7646   | 0.9557 |    94   |
# |      1       |  0.1474  |   0.5067  | 0.0863 |    0.9487   | 0.6297 |   881   |
# |      2       |  0.767   |   0.7001  | 0.848  |    0.4974   | 0.7029 |   1349  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.5314 |   2324  |
# |  marco avg   |  0.3206  |   0.4115  | 0.3646 |    0.7369   | 0.7628 |   2324  |
# | weighted avg |  0.503   |   0.5996  | 0.5314 |    0.6793   | 0.6854 |   2324  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.5342, 'auc-ci': 0.0015, 'auc-lower': 0.5328, 'auc-upper': 0.5357, 'f1-score': 0.0473, 'precision': 0.0278, 'recall': 0.1596, 'specificity': 0.7646, 'NPV': 0.9557, 'support': 94}, '1': {'auc': 0.5, 'auc-ci': 0.0007, 'auc-lower': 0.4993, 'auc-upper': 0.5008, 'f1-score': 0.1474, 'precision': 0.5067, 'recall': 0.0863, 'specificity': 0.9487, 'NPV': 0.6297, 'support': 881}, '2': {'auc': 0.7793, 'auc-ci': 0.0006, 'auc-lower': 0.7787, 'auc-upper': 0.7799, 'f1-score': 0.767, 'precision': 0.7001, 'recall': 0.848, 'specificity': 0.4974, 'NPV': 0.7029, 'support': 1349}, 'marco avg': {'f1-score': 0.3206, 'precision': 0.4115, 'recall': 0.3646, 'specificity': 0.7369, 'NPV': 0.7628, 'support': 2324}, 'weighted avg': {'f1-score': 0.503, 'precision': 0.5996, 'recall': 0.5314, 'specificity': 0.6793, 'NPV': 0.6854, 'support': 2324}, 'accuracy': 0.5314}
# ibc
# [[  48   96   57]
#  [ 180  375  661]
#  [  64  212 1404]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.7518 | 0.0009 |   0.7509  |   0.7527  |
# |   1   | 0.5565 | 0.0007 |   0.5559  |   0.5572  |
# |   2   | 0.7476 | 0.0006 |   0.747   |   0.7481  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.1947  |   0.1644  | 0.2388 |    0.9157   | 0.9455 |   201   |
# |      1       |  0.3949  |   0.549   | 0.3084 |    0.8363   | 0.6516 |   1216  |
# |      2       |  0.7386  |   0.6616  | 0.8357 |    0.4933   | 0.7169 |   1680  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.5899 |   3097  |
# |  marco avg   |  0.4427  |   0.4584  | 0.461  |    0.7484   | 0.7713 |   3097  |
# | weighted avg |  0.5683  |   0.5852  | 0.5899 |    0.6554   | 0.7061 |   3097  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.7518, 'auc-ci': 0.0009, 'auc-lower': 0.7509, 'auc-upper': 0.7527, 'f1-score': 0.1947, 'precision': 0.1644, 'recall': 0.2388, 'specificity': 0.9157, 'NPV': 0.9455, 'support': 201}, '1': {'auc': 0.5565, 'auc-ci': 0.0007, 'auc-lower': 0.5559, 'auc-upper': 0.5572, 'f1-score': 0.3949, 'precision': 0.549, 'recall': 0.3084, 'specificity': 0.8363, 'NPV': 0.6516, 'support': 1216}, '2': {'auc': 0.7476, 'auc-ci': 0.0006, 'auc-lower': 0.747, 'auc-upper': 0.7481, 'f1-score': 0.7386, 'precision': 0.6616, 'recall': 0.8357, 'specificity': 0.4933, 'NPV': 0.7169, 'support': 1680}, 'marco avg': {'f1-score': 0.4427, 'precision': 0.4584, 'recall': 0.461, 'specificity': 0.7484, 'NPV': 0.7713, 'support': 3097}, 'weighted avg': {'f1-score': 0.5683, 'precision': 0.5852, 'recall': 0.5899, 'specificity': 0.6554, 'NPV': 0.7061, 'support': 3097}, 'accuracy': 0.5899}

# %%
shandaer_root = pathlib.Path('/mnt/hd0/project_large_files/bcacad/patches/shandaer_test')
shandaer_save_root = pathlib.Path('/mnt/hd0/project_large_files/bcacad/patches/shandaer_test/test_ssl_features')
X, Y = get_X_Y(shandaer_root, shandaer_save_root, phases=['test'])

for task in tasks:
    model = mclf
    preds = model.predict(np.array(X[task]['test']))
    probs = model.predict_proba(np.array(X[task]['test']))
    probs = np.array(probs)
    if task == 'type':
        preds = preds[:, 0]
        probs = probs[0, :]
    else:
        preds = preds[:, 1]
        probs = probs[1, :]
    labels = np.array(Y[task]['test'])
    print(task)
    cm = confusion_matrix(labels, preds)
    plot_confusion_matrix(cm, class_names[task])
    print(report(labels, preds, probs, class_names[task]))
# Out:
# Processing test:   0%|          | 0/4545 [00:00<?, ?it/s]
# Processing test: 100%|██████████| 4545/4545 [00:01<00:00, 2796.88it/s]
# type
# /home/yuxin/miniconda3/envs/histosslscaling/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:1133: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /home/yuxin/miniconda3/envs/histosslscaling/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/yuxin/miniconda3/envs/histosslscaling/lib/python3.8/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/yuxin/miniconda3/envs/histosslscaling/lib/python3.8/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/yuxin/miniconda3/envs/histosslscaling/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/yuxin/miniconda3/envs/histosslscaling/lib/python3.8/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/yuxin/miniconda3/envs/histosslscaling/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [[   0    0    0]
#  [ 246 1934  316]
#  [  19  218 1812]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   |  nan   |  nan   |    nan    |    nan    |
# |   1   | 0.9258 | 0.0002 |   0.9256  |   0.9261  |
# |   2   | 0.9497 | 0.0002 |   0.9496  |   0.9499  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |   0.0    |    0.0    |  0.0   |    0.9417   |  1.0   |    0    |
# |      1       |  0.8322  |   0.8987  | 0.7748 |    0.8936   | 0.7651 |   2496  |
# |      2       |  0.8676  |   0.8515  | 0.8843 |    0.8734   | 0.9019 |   2049  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.8242 |   4545  |
# |  marco avg   |  0.5666  |   0.5834  | 0.5531 |    0.9029   | 0.889  |   4545  |
# | weighted avg |  0.8482  |   0.8774  | 0.8242 |    0.8845   | 0.8268 |   4545  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': nan, 'auc-ci': nan, 'auc-lower': nan, 'auc-upper': nan, 'f1-score': 0.0, 'precision': 0.0, 'recall': 0.0, 'specificity': 0.9417, 'NPV': 1.0, 'support': 0}, '1': {'auc': 0.9258, 'auc-ci': 0.0002, 'auc-lower': 0.9256, 'auc-upper': 0.9261, 'f1-score': 0.8322, 'precision': 0.8987, 'recall': 0.7748, 'specificity': 0.8936, 'NPV': 0.7651, 'support': 2496}, '2': {'auc': 0.9497, 'auc-ci': 0.0002, 'auc-lower': 0.9496, 'auc-upper': 0.9499, 'f1-score': 0.8676, 'precision': 0.8515, 'recall': 0.8843, 'specificity': 0.8734, 'NPV': 0.9019, 'support': 2049}, 'marco avg': {'f1-score': 0.5666, 'precision': 0.5834, 'recall': 0.5531, 'specificity': 0.9029, 'NPV': 0.889, 'support': 4545}, 'weighted avg': {'f1-score': 0.8482, 'precision': 0.8774, 'recall': 0.8242, 'specificity': 0.8845, 'NPV': 0.8268, 'support': 4545}, 'accuracy': 0.8242}
# nonibc
# [[105  30 113]
#  [255 166 721]
#  [174  94 838]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.7196 | 0.0009 |   0.7187  |   0.7206  |
# |   1   | 0.5501 | 0.0007 |   0.5494  |   0.5508  |
# |   2   | 0.638  | 0.0007 |   0.6373  |   0.6387  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.2685  |   0.1966  | 0.4234 |    0.8092   | 0.9271 |   248   |
# |      1       |  0.2318  |   0.5724  | 0.1454 |    0.9084   | 0.5576 |   1142  |
# |      2       |  0.6033  |   0.5012  | 0.7577 |     0.4     | 0.6748 |   1106  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.4443 |   2496  |
# |  marco avg   |  0.3679  |   0.4234  | 0.4421 |    0.7059   | 0.7198 |   2496  |
# | weighted avg |  0.4001  |   0.5035  | 0.4443 |    0.6733   | 0.6462 |   2496  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.7196, 'auc-ci': 0.0009, 'auc-lower': 0.7187, 'auc-upper': 0.7206, 'f1-score': 0.2685, 'precision': 0.1966, 'recall': 0.4234, 'specificity': 0.8092, 'NPV': 0.9271, 'support': 248}, '1': {'auc': 0.5501, 'auc-ci': 0.0007, 'auc-lower': 0.5494, 'auc-upper': 0.5508, 'f1-score': 0.2318, 'precision': 0.5724, 'recall': 0.1454, 'specificity': 0.9084, 'NPV': 0.5576, 'support': 1142}, '2': {'auc': 0.638, 'auc-ci': 0.0007, 'auc-lower': 0.6373, 'auc-upper': 0.6387, 'f1-score': 0.6033, 'precision': 0.5012, 'recall': 0.7577, 'specificity': 0.4, 'NPV': 0.6748, 'support': 1106}, 'marco avg': {'f1-score': 0.3679, 'precision': 0.4234, 'recall': 0.4421, 'specificity': 0.7059, 'NPV': 0.7198, 'support': 2496}, 'weighted avg': {'f1-score': 0.4001, 'precision': 0.5035, 'recall': 0.4443, 'specificity': 0.6733, 'NPV': 0.6462, 'support': 2496}, 'accuracy': 0.4443}
# ibc
# [[ 65   2  24]
#  [147 256 461]
#  [ 33 141 920]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.9156 | 0.0008 |   0.9147  |   0.9164  |
# |   1   | 0.6461 | 0.0007 |   0.6454  |   0.6469  |
# |   2   | 0.7481 | 0.0007 |   0.7474  |   0.7487  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.3869  |   0.2653  | 0.7143 |    0.9081   | 0.9856 |    91   |
# |      1       |  0.4054  |   0.6416  | 0.2963 |    0.8793   | 0.6315 |   864   |
# |      2       |  0.7363  |   0.6548  | 0.841  |    0.4921   | 0.7298 |   1094  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.6057 |   2049  |
# |  marco avg   |  0.5095  |   0.5206  | 0.6172 |    0.7598   | 0.7823 |   2049  |
# | weighted avg |  0.5812  |   0.6319  | 0.6057 |    0.6739   | 0.6997 |   2049  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.9156, 'auc-ci': 0.0008, 'auc-lower': 0.9147, 'auc-upper': 0.9164, 'f1-score': 0.3869, 'precision': 0.2653, 'recall': 0.7143, 'specificity': 0.9081, 'NPV': 0.9856, 'support': 91}, '1': {'auc': 0.6461, 'auc-ci': 0.0007, 'auc-lower': 0.6454, 'auc-upper': 0.6469, 'f1-score': 0.4054, 'precision': 0.6416, 'recall': 0.2963, 'specificity': 0.8793, 'NPV': 0.6315, 'support': 864}, '2': {'auc': 0.7481, 'auc-ci': 0.0007, 'auc-lower': 0.7474, 'auc-upper': 0.7487, 'f1-score': 0.7363, 'precision': 0.6548, 'recall': 0.841, 'specificity': 0.4921, 'NPV': 0.7298, 'support': 1094}, 'marco avg': {'f1-score': 0.5095, 'precision': 0.5206, 'recall': 0.6172, 'specificity': 0.7598, 'NPV': 0.7823, 'support': 2049}, 'weighted avg': {'f1-score': 0.5812, 'precision': 0.6319, 'recall': 0.6057, 'specificity': 0.6739, 'NPV': 0.6997, 'support': 2049}, 'accuracy': 0.6057}

# %%
apght_root = pathlib.Path('/mnt/hd0/project_large_files/bcacad/patches/2017_Agios_Pavlos_patch')
apght_save_root = pathlib.Path('/mnt/hd0/project_large_files/bcacad/patches/2017_Agios_Pavlos_patch_pretrian_ssl_features')
X, Y = get_X_Y(apght_root, apght_root, phases=['test'])

for task in ['ibc']:
    model = mclf
    preds = model.predict(np.array(X[task]['test']))
    probs = model.predict_proba(np.array(X[task]['test']))
    probs = np.array(probs)
    if task == 'type':
        preds = preds[:, 0]
        probs = probs[0, :]
    else:
        preds = preds[:, 1]
        probs = probs[1, :]
    labels = np.array(Y[task]['test'])
    print(task)
    cm = confusion_matrix(labels, preds)
    plot_confusion_matrix(cm, class_names[task])
    print(report(labels, preds, probs, class_names[task]))
# Out:
# Processing test:   0%|          | 0/300 [00:00<?, ?it/s]
# Processing test: 100%|██████████| 300/300 [00:06<00:00, 48.96it/s]
# ibc
# [[69 38  0]
#  [65 37  0]
#  [ 7 67 17]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.694  | 0.0019 |   0.6921  |   0.6959  |
# |   1   | 0.418  | 0.0021 |   0.4159  |    0.42   |
# |   2   | 0.7998 | 0.0017 |   0.7982  |   0.8015  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.5565  |   0.4894  | 0.6449 |    0.6269   | 0.761  |   107   |
# |      1       |  0.3033  |   0.2606  | 0.3627 |    0.4697   | 0.5886 |   102   |
# |      2       |  0.3148  |    1.0    | 0.1868 |     1.0     | 0.7385 |    91   |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             |  0.41  |   300   |
# |  marco avg   |  0.3915  |   0.5833  | 0.3981 |    0.6989   | 0.696  |   300   |
# | weighted avg |  0.3971  |   0.5665  |  0.41  |    0.6866   | 0.6956 |   300   |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.694, 'auc-ci': 0.0019, 'auc-lower': 0.6921, 'auc-upper': 0.6959, 'f1-score': 0.5565, 'precision': 0.4894, 'recall': 0.6449, 'specificity': 0.6269, 'NPV': 0.761, 'support': 107}, '1': {'auc': 0.418, 'auc-ci': 0.0021, 'auc-lower': 0.4159, 'auc-upper': 0.42, 'f1-score': 0.3033, 'precision': 0.2606, 'recall': 0.3627, 'specificity': 0.4697, 'NPV': 0.5886, 'support': 102}, '2': {'auc': 0.7998, 'auc-ci': 0.0017, 'auc-lower': 0.7982, 'auc-upper': 0.8015, 'f1-score': 0.3148, 'precision': 1.0, 'recall': 0.1868, 'specificity': 1.0, 'NPV': 0.7385, 'support': 91}, 'marco avg': {'f1-score': 0.3915, 'precision': 0.5833, 'recall': 0.3981, 'specificity': 0.6989, 'NPV': 0.696, 'support': 300}, 'weighted avg': {'f1-score': 0.3971, 'precision': 0.5665, 'recall': 0.41, 'specificity': 0.6866, 'NPV': 0.6956, 'support': 300}, 'accuracy': 0.41}

# %%
def get_Bracs_X_Y(data_root, save_root, phases=['test']):
    data_root = pathlib.Path(data_root)
    save_root = pathlib.Path(save_root)
    X={}
    Y={}
    for task in ['type']:
        X[task] = {}
        Y[task] = {}
        for phase in phases:
            X[task][phase] = []
            Y[task][phase] = []

    for phase in phases:
        tile_paths = []
        for l in ['0_N', '5_DCIS', '6_IC']:
            tile_paths.extend(list((data_root).glob(f'*/{l}/*.png')))
        for path in tqdm(tile_paths, desc=f'Processing {phase}'):
            save_path = save_root / path.parent.name / path.name /f'{path.stem}.npy' 
            if save_path.exists():
                feature = np.load(save_path)
            else:
                save_path.parent.mkdir(exist_ok=True, parents=True)
                im = Image.open(path)
                tensor = data_trans(im)
                batch = tensor.unsqueeze(0)
                batch = batch.to(device)
                feature = ibot_base_pancancer(batch).detach().cpu().numpy()
                feature = feature.flatten()
                np.save(save_path, feature)

            if path.parent.name == '0_N':
                type = 0
            elif path.parent.name == '5_DCIS':
                type = 1
            elif path.parent.name == '6_IC':
                type = 2
            
            X['type'][phase].append(feature)
            Y['type'][phase].append(type)

    return X, Y

# %%
X,Y = get_Bracs_X_Y('/mnt/hd0/project_large_files/bcacad/patches/bracs_patch/latest_version_patch', '/mnt/hd0/project_large_files/bcacad/patches/bracs_patch/latest_version_patch_pre_ssl_features', phases=['test'])
# Out:
# Processing test: 100%|██████████| 10094/10094 [04:51<00:00, 34.62it/s]

# %%
for task in ['type']:
    model = mclf
    preds = model.predict(np.array(X[task]['test']))
    probs = model.predict_proba(np.array(X[task]['test']))
    probs = np.array(probs)
    if task == 'type':
        preds = preds[:, 0]
        probs = probs[0, :]
    else:
        preds = preds[:, 1]
        probs = probs[1, :]
    labels = np.array(Y[task]['test'])
    print(task)
    cm = confusion_matrix(labels, preds)
    plot_confusion_matrix(cm, class_names[task])
    print(report(labels, preds, probs, class_names[task]))
# Out:
# type
# [[1329  338    5]
#  [  32 3526   64]
#  [  49 1300 3451]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.991  |  0.0   |   0.991   |   0.9911  |
# |   1   | 0.9338 | 0.0001 |   0.9336  |   0.9339  |
# |   2   | 0.9431 | 0.0001 |   0.943   |   0.9433  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.8624  |   0.9426  | 0.7949 |    0.9904   | 0.9605 |   1672  |
# |      1       |  0.8026  |   0.6828  | 0.9735 |    0.7469   | 0.9805 |   3622  |
# |      2       |  0.8296  |   0.9804  | 0.719  |    0.987    | 0.7948 |   4800  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.8229 |  10094  |
# |  marco avg   |  0.8315  |   0.8686  | 0.8291 |    0.9081   | 0.9119 |  10094  |
# | weighted avg |  0.8253  |   0.8673  | 0.8229 |    0.9014   | 0.8889 |  10094  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.991, 'auc-ci': 0.0, 'auc-lower': 0.991, 'auc-upper': 0.9911, 'f1-score': 0.8624, 'precision': 0.9426, 'recall': 0.7949, 'specificity': 0.9904, 'NPV': 0.9605, 'support': 1672}, '1': {'auc': 0.9338, 'auc-ci': 0.0001, 'auc-lower': 0.9336, 'auc-upper': 0.9339, 'f1-score': 0.8026, 'precision': 0.6828, 'recall': 0.9735, 'specificity': 0.7469, 'NPV': 0.9805, 'support': 3622}, '2': {'auc': 0.9431, 'auc-ci': 0.0001, 'auc-lower': 0.943, 'auc-upper': 0.9433, 'f1-score': 0.8296, 'precision': 0.9804, 'recall': 0.719, 'specificity': 0.987, 'NPV': 0.7948, 'support': 4800}, 'marco avg': {'f1-score': 0.8315, 'precision': 0.8686, 'recall': 0.8291, 'specificity': 0.9081, 'NPV': 0.9119, 'support': 10094}, 'weighted avg': {'f1-score': 0.8253, 'precision': 0.8673, 'recall': 0.8229, 'specificity': 0.9014, 'NPV': 0.8889, 'support': 10094}, 'accuracy': 0.8229}

# %%
def get_BACH_X_Y(data_root, save_root, phases=['test']):
    data_root = pathlib.Path(data_root)
    save_root = pathlib.Path(save_root)
    X={}
    Y={}
    for task in ['type']:
        X[task] = {}
        Y[task] = {}
        for phase in phases:
            X[task][phase] = []
            Y[task][phase] = []

    for phase in phases:
        tile_paths = []
        for l in ['Normal', 'InSitu', 'Invasive']:
            tile_paths.extend(list((data_root/l).glob('**/*.tif')))
        for path in tqdm(tile_paths, desc=f'Processing {phase}'):
            save_path = save_root / path.parent.name / path.name /f'{path.stem}.npy' 
            if save_path.exists():
                feature = np.load(save_path)
            else:
                save_path.parent.mkdir(exist_ok=True, parents=True)
                im = Image.open(path)
                tensor = data_trans(im)
                batch = tensor.unsqueeze(0)
                batch = batch.to(device)
                feature = ibot_base_pancancer(batch).detach().cpu().numpy()
                feature = feature.flatten()
                np.save(save_path, feature)

            if path.parent.name == 'Normal':
                type = 0
            elif path.parent.name == 'InSitu':
                type = 1
            elif path.parent.name == 'Invasive':
                type = 2
            
            X['type'][phase].append(feature)
            Y['type'][phase].append(type)

    return X, Y

# %%
X,Y = get_BACH_X_Y('/mnt/hd0/project_large_files/bcacad/patches/bach_patch/Photos_patch_tif', '/mnt/hd0/project_large_files/bcacad/patches/bach_patch/Photos_patch_tif_pre_ssl_features', phases=['test'])
# Out:
# Processing test: 100%|██████████| 1200/1200 [00:30<00:00, 39.57it/s]

# %%
for task in ['type']:
    model = mclf
    preds = model.predict(np.array(X[task]['test']))
    probs = model.predict_proba(np.array(X[task]['test']))
    probs = np.array(probs)
    if task == 'type':
        preds = preds[:, 0]
        probs = probs[0, :]
    else:
        preds = preds[:, 1]
        probs = probs[1, :]
    labels = np.array(Y[task]['test'])
    print(task)
    cm = confusion_matrix(labels, preds)
    plot_confusion_matrix(cm, class_names[task])
    print(report(labels, preds, probs, class_names[task]))
# Out:
# type
# [[281 112   7]
#  [ 25 337  38]
#  [  8 116 276]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.9569 | 0.0003 |   0.9566  |   0.9573  |
# |   1   | 0.8584 | 0.0007 |   0.8577  |   0.8591  |
# |   2   | 0.9135 | 0.0006 |   0.9129  |   0.9142  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.7871  |   0.8949  | 0.7025 |    0.9588   | 0.8657 |   400   |
# |      1       |  0.6984  |   0.5965  | 0.8425 |    0.715    | 0.9008 |   400   |
# |      2       |  0.7656  |   0.8598  |  0.69  |    0.9438   | 0.8589 |   400   |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.745  |   1200  |
# |  marco avg   |  0.7504  |   0.7837  | 0.745  |    0.8725   | 0.8751 |   1200  |
# | weighted avg |  0.7504  |   0.7837  | 0.745  |    0.8725   | 0.8751 |   1200  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.9569, 'auc-ci': 0.0003, 'auc-lower': 0.9566, 'auc-upper': 0.9573, 'f1-score': 0.7871, 'precision': 0.8949, 'recall': 0.7025, 'specificity': 0.9588, 'NPV': 0.8657, 'support': 400}, '1': {'auc': 0.8584, 'auc-ci': 0.0007, 'auc-lower': 0.8577, 'auc-upper': 0.8591, 'f1-score': 0.6984, 'precision': 0.5965, 'recall': 0.8425, 'specificity': 0.715, 'NPV': 0.9008, 'support': 400}, '2': {'auc': 0.9135, 'auc-ci': 0.0006, 'auc-lower': 0.9129, 'auc-upper': 0.9142, 'f1-score': 0.7656, 'precision': 0.8598, 'recall': 0.69, 'specificity': 0.9438, 'NPV': 0.8589, 'support': 400}, 'marco avg': {'f1-score': 0.7504, 'precision': 0.7837, 'recall': 0.745, 'specificity': 0.8725, 'NPV': 0.8751, 'support': 1200}, 'weighted avg': {'f1-score': 0.7504, 'precision': 0.7837, 'recall': 0.745, 'specificity': 0.8725, 'NPV': 0.8751, 'support': 1200}, 'accuracy': 0.745}

# %%
def get_BCNB_X_Y(data_root, save_root, phases=['test']):
    X={}
    Y={}
    for task in ['ibc']:
        X[task] = {}
        Y[task] = {}
        for phase in phases:
            X[task][phase] = []
            Y[task][phase] = []

    for phase in phases:
        phase_root = data_root
        tile_paths = list(phase_root.glob('**/*/*.jpg'))
        for path in tqdm(tile_paths, desc=f'Processing {phase}'):
            save_path = save_root / phase / path.parent.parent.name /f'{path.stem}.npy' 
            if save_path.exists():
                feature = np.load(save_path)
            else:
                save_path.parent.mkdir(exist_ok=True, parents=True)
                im = Image.open(path)
                tensor = data_trans(im)
                batch = tensor.unsqueeze(0)
                batch = batch.to(device)
                feature = ibot_base_pancancer(batch).detach().cpu().numpy()
                feature = feature.flatten()
                np.save(save_path, feature)

            grade = int(path.parent.parent.name.split('-')[-1])-1
            

            X['ibc'][phase].append(feature)
            Y['ibc'][phase].append(grade)
    return X, Y

# %%
bcnb_root = pathlib.Path('/mnt/hd0/project_large_files/bcacad/patches/bcnb/patches_test_10x')
bcnb_save_root = pathlib.Path('/mnt/hd0/project_large_files/bcacad/patches/bcnb/patches_test_10x_pre_ssl_features')
X, Y = get_BCNB_X_Y(bcnb_root, bcnb_save_root, phases=['test'])
# Out:
# Processing test: 100%|██████████| 9686/9686 [00:03<00:00, 2807.31it/s]

# %%
Y['ibc']['test'] = np.array(Y['ibc']['test'])
np.unique(Y['ibc']['test'], return_counts=True)
# Out:
# (array([0, 1, 2]), array([ 355, 5704, 3627]))

# %%
from metrics3 import report
for task in ['ibc']:
    model = mclf
    preds = model.predict(np.array(X[task]['test']))
    probs = model.predict_proba(np.array(X[task]['test']))
    probs = np.array(probs)
    if task == 'type':
        preds = preds[:, 0]
        probs = probs[0, :]
    else:
        preds = preds[:, 1]
        probs = probs[1, :]
    labels = np.array(Y[task]['test'])
    print(task)
    cm = confusion_matrix(labels, preds)
    plot_confusion_matrix(cm, class_names[task])
    print(report(labels, preds, probs, class_names[task]))
# Out:
# ibc
# [[ 212  125   18]
#  [2286 2606  812]
#  [1040 1884  703]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.6797 | 0.0008 |   0.6789  |   0.6805  |
# |   1   | 0.4662 | 0.0004 |   0.4659  |   0.4666  |
# |   2   | 0.5657 | 0.0004 |   0.5653  |   0.5661  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.1089  |   0.0599  | 0.5972 |    0.6436   | 0.9767 |   355   |
# |      1       |  0.5051  |   0.5647  | 0.4569 |    0.4955   | 0.3891 |   5704  |
# |      2       |  0.2725  |   0.4586  | 0.1938 |    0.863    | 0.6414 |   3627  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.3635 |   9686  |
# |  marco avg   |  0.2955  |   0.3611  | 0.416  |    0.6673   | 0.6691 |   9686  |
# | weighted avg |  0.4035  |   0.5064  | 0.3635 |    0.6385   | 0.5051 |   9686  |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# {'0': {'auc': 0.6797, 'auc-ci': 0.0008, 'auc-lower': 0.6789, 'auc-upper': 0.6805, 'f1-score': 0.1089, 'precision': 0.0599, 'recall': 0.5972, 'specificity': 0.6436, 'NPV': 0.9767, 'support': 355}, '1': {'auc': 0.4662, 'auc-ci': 0.0004, 'auc-lower': 0.4659, 'auc-upper': 0.4666, 'f1-score': 0.5051, 'precision': 0.5647, 'recall': 0.4569, 'specificity': 0.4955, 'NPV': 0.3891, 'support': 5704}, '2': {'auc': 0.5657, 'auc-ci': 0.0004, 'auc-lower': 0.5653, 'auc-upper': 0.5661, 'f1-score': 0.2725, 'precision': 0.4586, 'recall': 0.1938, 'specificity': 0.863, 'NPV': 0.6414, 'support': 3627}, 'marco avg': {'f1-score': 0.2955, 'precision': 0.3611, 'recall': 0.416, 'specificity': 0.6673, 'NPV': 0.6691, 'support': 9686}, 'weighted avg': {'f1-score': 0.4035, 'precision': 0.5064, 'recall': 0.3635, 'specificity': 0.6385, 'NPV': 0.5051, 'support': 9686}, 'accuracy': 0.3635}

# %%
a= report(labels, preds, probs, class_names[task])
# Out:
# [[ 212  125   18]
#  [2286 2606  812]
#  [1040 1884  703]]
#
# +-------+--------+--------+-----------+-----------+
# | class |  auc   | 95%ci  | auc_lower | auc_upper |
# +-------+--------+--------+-----------+-----------+
# |   0   | 0.6797 | 0.0008 |   0.6789  |   0.6805  |
# |   1   | 0.4662 | 0.0004 |   0.4659  |   0.4666  |
# |   2   | 0.5657 | 0.0004 |   0.5653  |   0.5661  |
# +-------+--------+--------+-----------+-----------+
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |    class     | f1-score | precision | recall | specificity |  NPV   | support |
# +--------------+----------+-----------+--------+-------------+--------+---------+
# |      0       |  0.1089  |   0.0599  | 0.5972 |    0.6436   | 0.9767 |   355   |
# |      1       |  0.5051  |   0.5647  | 0.4569 |    0.4955   | 0.3891 |   5704  |
# |      2       |  0.2725  |   0.4586  | 0.1938 |    0.863    | 0.6414 |   3627  |
# |              |          |           |        |             |        |         |
# |   accuracy   |          |           |        |             | 0.3635 |   9686  |
# |  marco avg   |  0.2955  |   0.3611  | 0.416  |    0.6673   | 0.6691 |   9686  |
# | weighted avg |  0.4035  |   0.5064  | 0.3635 |    0.6385   | 0.5051 |   9686  |
# +--------------+----------+-----------+--------+-------------+--------+---------+

# %%
a['0']['auc']
# Out:
# 0.6797
